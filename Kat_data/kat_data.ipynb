# %%
import pandas as pd                         
import numpy as np        
import pandas
from os import listdir
from os.path import isfile, join
import csv
from sqlalchemy import create_engine

# %%
stock_attendance_2017=pd.read_excel(('T19F206.xls'),
              sheet_name='Figure 1') 
stock_attendance_2017_df=pd.DataFrame(stock_attendance_2017)
stock_attendance_2017_df.head()
# Out:
#   Parc et fréquentation des hébergements collectifs en 2017  \
# 0                                                NaN
# 1                                                NaN
# 2                                             Hôtels
# 3                                          Campings3
# 4  Autres hébergements collectifs touristiques (A...
#
#                  Unnamed: 1                           Unnamed: 2  \
# 0                       NaN                                  NaN
# 1  Nombre d'établissements1  Nombre d'hébergements\nen milliers2
# 2                     17840                                  641
# 3                      8343                                  710
# 4                      3540                                  245
#
#                 Unnamed: 3                    Unnamed: 4  \
# 0                      NaN                           NaN
# 1  Taux d'occupation\nen %  Nuitées totales\nen millions
# 2                     61.2                         209.9
# 3                     35.5                           124
# 4                     62.2                          94.8
#
#                         Unnamed: 5
# 0                              NaN
# 1  Nuitées étrangères\nen millions
# 2                             75.7
# 3                             38.8
# 4                             18.3

# %%
#drop row 0
stock_attendance_2017_df=stock_attendance_2017_df.drop([0])

# %%
#drop Nan rows
stock_attendance_2017_df=stock_attendance_2017_df.drop([9,10,11,12,13])

# %%
#new header
new_header = stock_attendance_2017_df.iloc[0]

# %%
stock_attendance_2017_df.columns=new_header

# %%
#drop row 0
stock_attendance_2017_df=stock_attendance_2017_df.drop([1])

# %%
#rename columns
stock_attendance_2017_df.columns = stock_attendance_2017_df.columns.fillna('type')
stock_attendance_2017_df=stock_attendance_2017_df.rename(columns={"type": "Establishment", "Nombre d'établissements1": "Number_of_Establishments",
                                                                 "Nombre d'hébergements\nen milliers2":"Number_of_Accomidations(thousands)",
                                                                 "Taux d'occupation\nen %":"Occupancy_Rate%",
                                                                 "Nuitées totales\nen millions":"Total_Night(millions)",
                                                                 "Nuitées étrangères\nen millions":"Foreign_Overnight_Stays(millions)"})

# %%
stock_attendance_2017_df=stock_attendance_2017_df.rename(columns={"type": "Establishment", "Nombre d'établissements1": "Number_of_Establishments",
                                                                 "Number_of_Accomidations(thousands)":"Number_of_Accomidations",
                                                                 "Occupancy_Rate%":"Occupancy_Rate",
                                                                 "Total_Night(millions)":"Total_Night",
                                                                 "Foreign_Overnight_Stays(millions)":"Foreign_Overnight_Stays"})

# %%
#stock_attendance_2017_df

# %%
#stock_attendance_2017_df
#conect to local database
rds_connection_string = "postgres:Otis-1995@localhost:5432/france_tourism_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['stock_attendance_2017', 'sites_visited_2017']

# %%
stock_attendance_2017_df=stock_attendance_2017_df.reset_index()

# %%
stock_attendance_2017_df=stock_attendance_2017_df.rename(columns={"index":"id"})

# %%
stock_attendance_2017_df.to_sql(name='stock_attendance_2017', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#
# UniqueViolation: duplicate key value violates unique constraint "stock_attendance_2017_pkey"
# DETAIL:  Key (id)=(2) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-15-c7310886de24> in <module>
# ----> 1 stock_attendance_2017_df.to_sql(name='stock_attendance_2017', con=engine, if_exists='append', index=False)
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2774         from pandas.io import sql
#    2775
# -> 2776         sql.to_sql(
#    2777             self,
#    2778             name,
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     588         )
#     589
# --> 590     pandas_sql.to_sql(
#     591         frame,
#     592         name,
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1403                 raise ValueError("inf cannot be used with MySQL") from err
#    1404             else:
# -> 1405                 raise err
#    1406
#    1407         if not name.isdigit() and not name.islower():
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1395
#    1396         try:
# -> 1397             table.insert(chunksize, method=method)
#    1398         except exc.SQLAlchemyError as err:
#    1399             # GH34431
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     829
#     830                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 831                 exec_insert(conn, keys, chunk_iter)
#     832
#     833     def _query_iterator(
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     746         """
#     747         data = [dict(zip(keys, row)) for row in data_iter]
# --> 748         conn.execute(self.table.insert(), data)
#     749
#     750     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1122             )
#    1123
# -> 1124         ret = self._execute_context(
#    1125             dialect,
#    1126             dialect.execution_ctx_cls._init_compiled,
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1314
#    1315         except BaseException as e:
# -> 1316             self._handle_dbapi_exception(
#    1317                 e, statement, parameters, cursor, context
#    1318             )
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1508                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1509             elif should_wrap:
# -> 1510                 util.raise_(
#    1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1254                             break
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     896     def do_executemany(self, cursor, statement, parameters, context=None):
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#     900
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "stock_attendance_2017_pkey"
# DETAIL:  Key (id)=(2) already exists.
#
# [SQL: INSERT INTO stock_attendance_2017 (id, "Establishment", "Number_of_Establishments", "Number_of_Accomidations", "Occupancy_Rate", "Total_Night", "Foreign_Overnight_Stays") VALUES (%(id)s, %(Establishment)s, %(Number_of_Establishments)s, %(Number_of_Accomidations)s, %(Occupancy_Rate)s, %(Total_Night)s, %(Foreign_Overnight_Stays)s)]
# [parameters: ({'id': 2, 'Establishment': 'Hôtels', 'Number_of_Establishments': 17840, 'Number_of_Accomidations': 641, 'Occupancy_Rate': 61.2, 'Total_Night': 209.9, 'Foreign_Overnight_Stays': 75.7}, {'id': 3, 'Establishment': 'Campings3', 'Number_of_Establishments': 8343, 'Number_of_Accomidations': 710, 'Occupancy_Rate': 35.5, 'Total_Night': 124, 'Foreign_Overnight_Stays': 38.8}, {'id': 4, 'Establishment': 'Autres hébergements collectifs touristiques (AHCT)', 'Number_of_Establishments': 3540, 'Number_of_Accomidations': 245, 'Occupancy_Rate': 62.2, 'Total_Night': 94.8, 'Foreign_Overnight_Stays': 18.3}, {'id': 5, 'Establishment': '\xa0\xa0\xa0Résidences de tourisme', 'Number_of_Establishments': 2347, 'Number_of_Accomidations': 172, 'Occupancy_Rate': 64.7, 'Total_Night': 71, 'Foreign_Overnight_Stays': 15.5}, {'id': 6, 'Establishment': '\xa0\xa0\xa0Villages de vacances', 'Number_of_Establishments': 946, 'Number_of_Accomidations': 64, 'Occupancy_Rate': 54.6, 'Total_Night': 20.3, 'Foreign_Overnight_Stays': 2}, {'id': 7, 'Establishment': '\xa0\xa0\xa0Autres ', 'Number_of_Establishments': 247, 'Number_of_Accomidations': 9, 'Occupancy_Rate': 57.3, 'Total_Night': 3.5, 'Foreign_Overnight_Stays': 0.8}, {'id': 8, 'Establishment': 'Ensemble ', 'Number_of_Establishments': 29723, 'Number_of_Accomidations': 1596, 'Occupancy_Rate': 53.9, 'Total_Night': 428.7, 'Foreign_Overnight_Stays': 132.8})]
# (Background on this error at: http://sqlalche.me/e/13/gkpj)

# %%
sites_visited_2017=pd.read_excel(('T19F206.xls'),
              sheet_name='Figure 2') 
sites_visited_2017_df=pd.DataFrame(sites_visited_2017)
sites_visited_2017_df.head()
# Out:
#   Monuments, sites culturels et récréatifs les plus fréquentés en 2017  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                         Disneyland
# 4                                   Musée du Louvre
#
#                  Unnamed: 1
# 0                       NaN
# 1  en milliers de visiteurs
# 2                 Visiteurs
# 3                     14860
# 4                    8022.3

# %%
 #dop frist 3 rows
sites_visited_2017_df=sites_visited_2017_df.drop([0,1,2])

# %%
sites_visited_2017_df=sites_visited_2017_df.rename(columns={"Monuments, sites culturels et récréatifs les plus fréquentés en 2017":"Sites",
                                                            "Unnamed: 1":"Number_of_Visitors_Millions"})

# %%
sites_visited_2017_df=sites_visited_2017_df.reset_index()

# %%
sites_visited_2017_df=sites_visited_2017_df.rename(columns={"index":"id"})

# %%
sites_visited_2017_df=sites_visited_2017_df.drop([19])

# %%
sites_visited_2017_df=sites_visited_2017_df.drop([15,16,17,18])

# %%
sites_visited_2017_df.to_sql(name='sites_visited_2017', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#
# UniqueViolation: duplicate key value violates unique constraint "sites_visited_2017_pkey"
# DETAIL:  Key (id)=(3) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-23-8697f5d9e833> in <module>
# ----> 1 sites_visited_2017_df.to_sql(name='sites_visited_2017', con=engine, if_exists='append', index=False)
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2774         from pandas.io import sql
#    2775
# -> 2776         sql.to_sql(
#    2777             self,
#    2778             name,
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     588         )
#     589
# --> 590     pandas_sql.to_sql(
#     591         frame,
#     592         name,
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1403                 raise ValueError("inf cannot be used with MySQL") from err
#    1404             else:
# -> 1405                 raise err
#    1406
#    1407         if not name.isdigit() and not name.islower():
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1395
#    1396         try:
# -> 1397             table.insert(chunksize, method=method)
#    1398         except exc.SQLAlchemyError as err:
#    1399             # GH34431
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     829
#     830                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 831                 exec_insert(conn, keys, chunk_iter)
#     832
#     833     def _query_iterator(
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     746         """
#     747         data = [dict(zip(keys, row)) for row in data_iter]
# --> 748         conn.execute(self.table.insert(), data)
#     749
#     750     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1122             )
#    1123
# -> 1124         ret = self._execute_context(
#    1125             dialect,
#    1126             dialect.execution_ctx_cls._init_compiled,
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1314
#    1315         except BaseException as e:
# -> 1316             self._handle_dbapi_exception(
#    1317                 e, statement, parameters, cursor, context
#    1318             )
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1508                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1509             elif should_wrap:
# -> 1510                 util.raise_(
#    1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1254                             break
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     896     def do_executemany(self, cursor, statement, parameters, context=None):
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#     900
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "sites_visited_2017_pkey"
# DETAIL:  Key (id)=(3) already exists.
#
# [SQL: INSERT INTO sites_visited_2017 (id, "Sites", "Number_of_Visitors_Millions") VALUES (%(id)s, %(Sites)s, %(Number_of_Visitors_Millions)s)]
# [parameters: ({'id': 3, 'Sites': 'Disneyland', 'Number_of_Visitors_Millions': 14860}, {'id': 4, 'Sites': 'Musée du Louvre ', 'Number_of_Visitors_Millions': 8022.3}, {'id': 5, 'Sites': 'Domaine de Versailles1', 'Number_of_Visitors_Millions': 7714.389}, {'id': 6, 'Sites': 'Tour Eiffel ', 'Number_of_Visitors_Millions': 6207.303}, {'id': 7, 'Sites': 'Centre Pompidou', 'Number_of_Visitors_Millions': 3337.872}, {'id': 8, 'Sites': "Musée d'Orsay ", 'Number_of_Visitors_Millions': 3177.842}, {'id': 9, 'Sites': "Cité des sciences et de l'industrie de La Villette   ", 'Number_of_Visitors_Millions': 2439.072}, {'id': 10, 'Sites': 'Le Puy du Fou2', 'Number_of_Visitors_Millions': 2260}  ... displaying 10 of 15 total bound parameter sets ...  {'id': 16, 'Sites': 'Château des Ducs de Bretagne ', 'Number_of_Visitors_Millions': 1471.741}, {'id': 17, 'Sites': 'Zoo parc de Beauval ', 'Number_of_Visitors_Millions': 1440.694})]
# (Background on this error at: http://sqlalche.me/e/13/gkpj)

# %%
origin_attendance_2017=pd.read_excel(('T19F206.xls'),
              sheet_name='Figure 3') 
origin_attendance_2017_df=pd.DataFrame(origin_attendance_2017)
origin_attendance_2017_df.head()
# Out:
#   Fréquentation des hébergements collectifs selon la provenance de la clientèle en 2017  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                             France
# 4                                           Étranger
#
#     Unnamed: 1              Unnamed: 2
# 0          NaN                     NaN
# 1          NaN  en millions de nuitées
# 2  2017.000000             17/16\nen %
# 3   295.963903                5.035282
# 4   132.754125                6.754425

# %%
#drop nan and non-data rows
origin_attendance_2017_df=origin_attendance_2017_df.drop([0,1,2,23,24])

# %%
#rename columns 
origin_attendance_2017_df=origin_attendance_2017_df.rename(columns={"Fréquentation des hébergements collectifs selon la provenance de la clientèle en 2017":"attendance_origin",
                                                                   "Unnamed: 1":"overnights_mil",
                                                                  "Unnamed: 2":"percentage_change_from_prev_yr"})
#reset index
origin_attendance_2017_df=origin_attendance_2017_df.reset_index()
origin_attendance_2017_df=origin_attendance_2017_df.rename(columns={"index":"id"})

# %%
#send to db
origin_attendance_2017_df.to_sql(name='origin_attendance', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#
# UniqueViolation: duplicate key value violates unique constraint "origin_attendance_pkey"
# DETAIL:  Key (id)=(3) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-47-4f6f9a717615> in <module>
#       1 #send to db
# ----> 2 origin_attendance_2017_df.to_sql(name='origin_attendance', con=engine, if_exists='append', index=False)
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2774         from pandas.io import sql
#    2775
# -> 2776         sql.to_sql(
#    2777             self,
#    2778             name,
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     588         )
#     589
# --> 590     pandas_sql.to_sql(
#     591         frame,
#     592         name,
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1403                 raise ValueError("inf cannot be used with MySQL") from err
#    1404             else:
# -> 1405                 raise err
#    1406
#    1407         if not name.isdigit() and not name.islower():
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1395
#    1396         try:
# -> 1397             table.insert(chunksize, method=method)
#    1398         except exc.SQLAlchemyError as err:
#    1399             # GH34431
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     829
#     830                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 831                 exec_insert(conn, keys, chunk_iter)
#     832
#     833     def _query_iterator(
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     746         """
#     747         data = [dict(zip(keys, row)) for row in data_iter]
# --> 748         conn.execute(self.table.insert(), data)
#     749
#     750     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1122             )
#    1123
# -> 1124         ret = self._execute_context(
#    1125             dialect,
#    1126             dialect.execution_ctx_cls._init_compiled,
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1314
#    1315         except BaseException as e:
# -> 1316             self._handle_dbapi_exception(
#    1317                 e, statement, parameters, cursor, context
#    1318             )
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1508                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1509             elif should_wrap:
# -> 1510                 util.raise_(
#    1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1254                             break
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     896     def do_executemany(self, cursor, statement, parameters, context=None):
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#     900
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "origin_attendance_pkey"
# DETAIL:  Key (id)=(3) already exists.
#
# [SQL: INSERT INTO origin_attendance (id, attendance_origin, overnights_mil, percentage_change_from_prev_yr) VALUES (%(id)s, %(attendance_origin)s, %(overnights_mil)s, %(percentage_change_from_prev_yr)s)]
# [parameters: ({'id': 3, 'attendance_origin': 'France', 'overnights_mil': 295.963902879624, 'percentage_change_from_prev_yr': 5.03528181272876}, {'id': 4, 'attendance_origin': 'Étranger', 'overnights_mil': 132.754125114345, 'percentage_change_from_prev_yr': 6.75442505370114}, {'id': 5, 'attendance_origin': 'Europe hors France', 'overnights_mil': 102.311160978878, 'percentage_change_from_prev_yr': 4.78133967532217}, {'id': 6, 'attendance_origin': 'dont : Allemagne', 'overnights_mil': 17.1159321657055, 'percentage_change_from_prev_yr': 7.07621011377186}, {'id': 7, 'attendance_origin': '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Belgique', 'overnights_mil': 13.3875065995506, 'percentage_change_from_prev_yr': 3.83945959576091}, {'id': 8, 'attendance_origin': '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Espagne', 'overnights_mil': 7.70694054650263, 'percentage_change_from_prev_yr': 15.314525742427}, {'id': 9, 'attendance_origin': '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Italie', 'overnights_mil': 6.47404887878923, 'percentage_change_from_prev_yr': 6.78993640994718}, {'id': 10, 'attendance_origin': '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Pays-Bas', 'overnights_mil': 17.9977603236047, 'percentage_change_from_prev_yr': 5.00959051244787}  ... displaying 10 of 20 total bound parameter sets ...  {'id': 21, 'attendance_origin': 'Afrique', 'overnights_mil': 1.76024371377538, 'percentage_change_from_prev_yr': 6.72561509107161}, {'id': 22, 'attendance_origin': 'Total', 'overnights_mil': 428.71802799397, 'percentage_change_from_prev_yr': 5.56162479059619})]
# (Background on this error at: http://sqlalche.me/e/13/gkpj)

# %%
dom_tour_consumption=pd.read_excel(('T19F206.xls'),
              sheet_name='Figure 4') 
dom_tour_consumption_df=pd.DataFrame(dom_tour_consumption)
dom_tour_consumption_df
# Out:
#           Consommation touristique intérieure en 2017   Unnamed: 1  \
# 0                                                 NaN          NaN
# 1                                                 NaN          NaN
# 2                                                 NaN  2013.000000
# 3                      Dépense touristique intérieure   140.067892
# 4                Hébergements touristiques marchands     30.760564
# 5                               Restaurants et cafés     16.031694
# 6                               Aliments et boissons     12.439159
# 7                      Serv. de transport non urbain     27.823011
# 8   Péages, carburants, location de véhicules de t...    16.570206
# 9      Services des voyagistes et agences de voyages      7.247000
# 10    Activités culturelles, sportives et de loisirs      8.469102
# 11                                   Autres dépenses1    20.727156
# 12            Hébergements touristiques non marchands    19.051752
# 13                Consommation touristique intérieure   159.119643
# 14            1. Transports sur place, shopping, etc.          NaN
# 15  Source : DGE, compte satellite du tourisme, ba...          NaN
#
#      Unnamed: 2   Unnamed: 3   Unnamed: 4            Unnamed: 5
# 0           NaN          NaN          NaN                   NaN
# 1           NaN          NaN          NaN  en milliards d’euros
# 2   2014.000000  2015.000000  2016.000000                  2017
# 3    141.486408   141.508848   138.893016            148.361297
# 4     31.245199    31.441177    29.896135             32.058217
# 5     16.265275    16.346349    15.601195             16.710100
# 6     12.582360    12.618114    12.330291             13.093600
# 7     27.797469    29.450758    28.722902             30.972553
# 8     16.735058    15.791057    15.109627             16.028304
# 9      7.333000     7.640000     7.792000              8.194000
# 10     8.703333     8.939282     9.144538              9.673188
# 11    20.824714    19.282111    20.296328             21.631335
# 12    19.198289    19.347451    19.483988             19.606688
# 13   160.684697   160.856299   158.377004            167.967985
# 14          NaN          NaN          NaN                   NaN
# 15          NaN          NaN          NaN                   NaN

# %%
dom_tour_consumption_df=dom_tour_consumption_df.drop([0,1,14,15])

# %%
dom_tour_consumption_df=dom_tour_consumption_df.rename(columns={"Consommation touristique intérieure en 2017":"domestic_accomidations",
                                                                "Unnamed: 1":"2013","Unnamed: 2":"2014","Unnamed: 3":"2015",
                                                                "Unnamed: 4":"2016","Unnamed: 5":"2017"})

# %%
dom_tour_consumption_df=dom_tour_consumption_df.drop([2])

# %%
dom_tour_consumption_df=dom_tour_consumption_df.rename(columns={"Domestic Accomidations":"domestic_accomidations"})

# %%
dom_tour_consumption_df=dom_tour_consumption_df.rename(columns={"2013":"yr_2013","2014":"yr_2014","2015":"yr_2015",
                                                                "2016":"yr_2016","2017":"yr_2017"})

# %%
#reset index
dom_tour_consumption_df=dom_tour_consumption_df.reset_index()
dom_tour_consumption_df=dom_tour_consumption_df.rename(columns={"index":"id"})

# %%
#check tables
engine.table_names()
# Out:
# ['stock_attendance_2017',
#  'sites_visited_2017',
#  'origin_attendance',
#  'dom_tour_consumption']

# %%
dom_tour_consumption_df.head()
# Out:
#    id                domestic_accomidations     yr_2013     yr_2014  \
# 0   3        Dépense touristique intérieure  140.067892  141.486408
# 1   4  Hébergements touristiques marchands    30.760564   31.245199
# 2   5                 Restaurants et cafés    16.031694   16.265275
# 3   6                 Aliments et boissons    12.439159   12.582360
# 4   7        Serv. de transport non urbain    27.823011   27.797469
#
#       yr_2015     yr_2016     yr_2017
# 0  141.508848  138.893016  148.361297
# 1   31.441177   29.896135   32.058217
# 2   16.346349   15.601195   16.710100
# 3   12.618114   12.330291   13.093600
# 4   29.450758   28.722902   30.972553

# %%
#send to db
dom_tour_consumption_df.to_sql(name='dom_tour_consumption', con=engine, if_exists='append', index=False)

# %%
EU_attendance=pd.read_excel(('T19F206.xls'),
              sheet_name='Figure 5') 
EU_attendance_2017_df=pd.DataFrame(EU_attendance)
EU_attendance_2017_df
# Out:
#    Fréquentation des hébergements collectifs dans quelques pays de l'UE en 2017  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                           Allemagne
# 3                                            Autriche
# 4                                            Belgique
# 5                                             Croatie
# 6                                             Espagne
# 7                                              France
# 8                                               Grèce
# 9                                              Italie
# 10                                           Pays-Bas
# 11                                            Pologne
# 12                                           Portugal
# 13                                       Rép. tchèque
# 14                                       Royaume-Uni1
# 15                                              Suède
# 16                                                UE1
# 17                                   1. Données 2016.
# 18  Source : Eurostat (extraction du 3 décembre 20...
#
#               Unnamed: 1                          Unnamed: 2
# 0                    NaN                                 NaN
# 1   Nuitées\nen millions  Nuitées des    non-résidents\nen %
# 2             401.163218                               20.72
# 3             121.126543                               71.04
# 4              38.677308                               48.24
# 5              86.094847                               93.13
# 6             471.199729                               64.92
# 7             433.058728                               30.83
# 8             111.271482                               80.24
# 9             420.629155                               50.08
# 10            111.697814                               39.54
# 11             83.880915                               19.92
# 12             72.035786                               67.86
# 13             53.219395                               49.34
# 14            476.356101                               58.66
# 15             58.683201                               24.95
# 16           3053.897521                               48.59
# 17                   NaN                                 NaN
# 18                   NaN                                 NaN

# %%
EU_attendance_2017_df=EU_attendance_2017_df.rename(columns={"Fréquentation des hébergements collectifs dans quelques pays de l'UE en 2017":"eu_countries",
                                                           "Unnamed: 1":"overnight_stays_mil","Unnamed: 2":"non_res_overnights_mil"})

# %%
EU_attendance_2017_df=EU_attendance_2017_df.drop([0,1,16,17,18])

# %%
#rest index
EU_attendance_2017_df=EU_attendance_2017_df.reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-9570261cbd2a> in <module>
#       1 #rest index
# ----> 2 EU_attendance_2017_df=EU_attendance_2017_df.reset_index()
#       3 EU_attendance_2017_df=EU_attendance_2017_df.rename(columns={"index":"id"})
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5011                 # to ndarray and maybe infer different dtype
#    5012                 level_values = maybe_casted_values(lev, lab)
# -> 5013                 new_obj.insert(0, name, level_values)
#    5014
#    5015         new_obj.index = new_index
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3758         self._ensure_valid_index(value)
#    3759         value = self._sanitize_column(column, value, broadcast=False)
# -> 3760         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3761
#    3762     def assign(self, **kwargs) -> DataFrame:
#
# ~/opt/anaconda3/envs/BC_u12/lib/python3.8/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1189         if not allow_duplicates and item in self.items:
#    1190             # Should this be a different kind of error??
# -> 1191             raise ValueError(f"cannot insert {item}, already exists")
#    1192
#    1193         if not isinstance(loc, int):
#
# ValueError: cannot insert level_0, already exists

# %%
EU_attendance_2017_df=EU_attendance_2017_df.rename(columns={"index":"id"})

# %%
EU_attendance_2017_df=EU_attendance_2017_df.drop(columns=["level_0"])

# %%
EU_attendance_2017_df.to_sql(name='eu_attendance', con=engine, if_exists='append', index=False)

# %%
#sheet 6
int_receipts=pd.read_excel(('T19F206.xls'),
              sheet_name='Figure 6') 
int_receipts_2017_df=pd.DataFrame(int_receipts)
int_receipts_2017_df.head()
# Out:
#   Unnamed: 0      Unnamed: 1   Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 0        NaN             NaN          NaN         NaN        NaN
# 1       Rang  Pays récepteur  1990.000000    2000.000   2017 (p)
# 2          1      États-Unis    33.837056     108.500      186.6
# 3          2         Espagne    14.542845      33.400       60.3
# 4          3          France    15.881158      35.705       53.7
#
#                            Unnamed: 5
# 0                en milliards d'euros
# 1  Évolution annuelle\n2017/2000 en %
# 2                            3.240923
# 3                            3.536243
# 4                            2.429768

# %%
#int_receipts_2017_df=int_receipts_2017_df.rename(columns=int_receipts_2017_df.iloc[])

# %%
int_receipts_2017_df=int_receipts_2017_df.rename(columns={"Unnamed: 0":"rank",
                                                         "Unnamed: 1":"receiving_country",
                                                         "Unnamed: 2":"yr_1990",
                                                         "Unnamed: 3":"yr_2000",
                                                         "Unnamed: 4":"yr_2017",
                                                         "Unnamed: 5":"change_from_2000"})

# %%
int_receipts_2017_df=int_receipts_2017_df.drop([0,1,22,23,24,25,26,27])

# %%
int_receipts_2017_df=int_receipts_2017_df.drop(columns="rank")

# %%
int_receipts_2017_df=int_receipts_2017_df.reset_index()
int_receipts_2017_df=int_receipts_2017_df.rename(columns={"index":"id"})

# %%
int_receipts_2017_df
# Out:
#     id    receiving_country    yr_1990     yr_2000 yr_2017 change_from_2000
# 0    2           États-Unis  33.837056  108.500000   186.6         3.240923
# 1    3              Espagne  14.542845   33.400000    60.3         3.536243
# 2    4               France  15.881158   35.705000    53.7         2.429768
# 3    5            Thaïlande   3.403611    8.104798    50.9        11.413994
# 4    6          Royaume-Uni  12.096746   23.654235    45.3         3.896130
# 5    7               Italie  12.948829   29.753666    39.2         1.635133
# 6    8            Australie   3.340669   10.036573    36.9         7.959591
# 7    9            Allemagne  11.207684   20.230069    35.3         3.328993
# 8   10                Macao   0.000000    3.471784    31.5        13.851484
# 9   11                Japon   0.000000    3.700000    30.1        13.122988
# 10  12            Hong Kong   3.959078    6.392715    29.5         9.412481
# 11  13               Chine1   1.745078   17.565626    28.9         2.972121
# 12  14                 Inde   0.000000    3.744505    24.2        11.601959
# 13  15              Turquie   2.537366    8.263885    19.9         5.305513
# 14  16              Mexique   0.000000    9.000000    18.9         4.460975
# 15  17  Émirats arabes unis   0.000000    0.000000    18.6                0
# 16  18             Autriche  10.556230   10.588509    18.1         3.204039
# 17  19               Canada   4.987400   11.664242      18         2.584865
# 18  20            Singapour   0.000000    5.564811    17.4         6.935883
# 19  21             Malaisie   1.311563    5.423039    16.2         6.649099

# %%
int_receipts_2017_df.to_sql(name='international_receipts', con=engine, if_exists='append', index=False)
